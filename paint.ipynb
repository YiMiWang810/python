# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mul(a,b):
    c = a**2 + b
    return c
x = np.arange(0,100,.5)
y = mul(x,2)

# %%
i = 1
reward_ = []
step_ = []
reward_ = []
step_ = []
for i in range(100):
    reward = i**3 + 2
    reward_.append(reward)   #append返回None,写成s=reward_.append(reward),print(s) ,会报错
    step_.append(i)

# %%
plt.plot(step_,reward_)
plt.ylabel("Reward")
plt.show()
